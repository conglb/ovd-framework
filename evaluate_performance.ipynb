# %% [markdown]
# #### Evaludate

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
m1 = './data-collection/performance_log.log'
m2 = './data-cleaning/performance_log.log'
m3 = './data-storage/performance_log.log'
m4 = './data-presentation/performance_log.log'

df1 = pd.read_csv(m1)
df2 = pd.read_csv(m2)

# %%
df['m1_Cumulative_File_Size'] = df['File_size'].cumsum()
df['m1_Cumulative_Time'] = df['Time'].cumsum()

# Scale the data
max_file_size = 1 * 1024**3  # 1GB in bytes
max_time = 10  # 10 seconds


# Plot the scaled cumulative data
plt.figure(figsize=(8, 6))
plt.plot(df['m1_Cumulative_File_Size'], df['m1_Cumulative_Time'], marker='o', linestyle='-', color='b')
plt.xlabel('Cumulative File Size (scaled to 1GB)', fontsize=12)
plt.ylabel('Cumulative Time Taken (scaled to 10s)', fontsize=12)
plt.title('Cumulative File Size vs Time Taken to Process (Scaled)', fontsize=14)
plt.grid(True)
plt.show()

# %%
df['m2_File_Size'] = df2['File_size'].cumsum()
df['m2_Time'] = df2['Time'].cumsum()

# Scale the data
max_file_size = 1 * 1024**3  # 1GB in bytes
max_time = 10  # 10 seconds


# Plot the scaled cumulative data
plt.figure(figsize=(8, 6))
plt.plot(df['m2_File_Size'], df['m2_Time'], marker='o', linestyle='-', color='b')
plt.xlabel('Cumulative File Size (scaled to 1GB)', fontsize=12)
plt.ylabel('Cumulative Time Taken (scaled to 10s)', fontsize=12)
plt.title('Cumulative File Size vs Time Taken to Process (Scaled)', fontsize=14)
plt.grid(True)
plt.show()

# %%
df['m2_File_Size'] = df2['File_size'].cumsum()
df['m2_Time'] = df2['Time'].cumsum()
df['m1_File_Size'] = df1['File_size'].cumsum()
df['m1_Time'] = df1['Time'].cumsum()

# Plot the scaled cumulative data
plt.figure(figsize=(8, 6))
plt.plot(df['m1_File_Size'], df['m1_Time'], marker='o', linestyle='-', color='b')
plt.plot(df['m2_File_Size'], df['m2_Time'], marker='o', linestyle='-', color='r')
plt.xlabel('Cumulative File Size', fontsize=12)
plt.ylabel('Cumulative Time Taken', fontsize=12)
plt.title('Cumulative File Size vs Time Taken to Process (Scaled)', fontsize=14)
plt.grid(True)
plt.show()
